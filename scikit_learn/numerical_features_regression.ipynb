# %%
import pandas as pd
import os
import pathlib
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder

# %%
# Set universal paths to enable easier navigation
root = pathlib.Path.cwd()
root_parent = root.parent

#Declare the data path
data = root_parent/"data"
# Out:
# PosixPath('/Users/aloo/dev/ml/data')

# %%
#Import the data Frame
df = pd.read_csv(data/"housing.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
#Choice of quantitative columns for normalization
columns = ["LotArea", "YearBuilt", "OverallQual", "1stFlrSF", "2ndFlrSF", "SalePrice"]

# %%
#Create a new dataframe based on the columns to be normalized
new_df = df[columns]
new_df
# Out:
#       LotArea  YearBuilt  OverallQual  1stFlrSF  2ndFlrSF  SalePrice
# 0        8450       2003            7       856       854     208500
# 1        9600       1976            6      1262         0     181500
# 2       11250       2001            7       920       866     223500
# 3        9550       1915            7       961       756     140000
# 4       14260       2000            8      1145      1053     250000
# ...       ...        ...          ...       ...       ...        ...
# 1455     7917       1999            6       953       694     175000
# 1456    13175       1978            6      2073         0     210000
# 1457     9042       1941            7      1188      1152     266500
# 1458     9717       1950            5      1078         0     142125
# 1459     9937       1965            5      1256         0     147500
#
# [1460 rows x 6 columns]

# %%
#create a correlation matrix to identify the features to select 
correlation_matrix = new_df.corr()
correlation_matrix.style.background_gradient(cmap = "gray")
# Out:
# <style type="text/css">
# #T_2063c_row0_col0, #T_2063c_row1_col1, #T_2063c_row2_col2, #T_2063c_row3_col3, #T_2063c_row4_col4, #T_2063c_row5_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_2063c_row0_col1 {
#   background-color: #010101;
#   color: #f1f1f1;
# }
# #T_2063c_row0_col2, #T_2063c_row0_col5, #T_2063c_row1_col0, #T_2063c_row3_col4, #T_2063c_row4_col1, #T_2063c_row4_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_2063c_row0_col3, #T_2063c_row2_col4, #T_2063c_row3_col2 {
#   background-color: #6a6a6a;
#   color: #f1f1f1;
# }
# #T_2063c_row0_col4 {
#   background-color: #353535;
#   color: #f1f1f1;
# }
# #T_2063c_row1_col2 {
#   background-color: #858585;
#   color: #f1f1f1;
# }
# #T_2063c_row1_col3 {
#   background-color: #676767;
#   color: #f1f1f1;
# }
# #T_2063c_row1_col4 {
#   background-color: #2d2d2d;
#   color: #f1f1f1;
# }
# #T_2063c_row1_col5 {
#   background-color: #5a5a5a;
#   color: #f1f1f1;
# }
# #T_2063c_row2_col0 {
#   background-color: #171717;
#   color: #f1f1f1;
# }
# #T_2063c_row2_col1 {
#   background-color: #919191;
#   color: #f1f1f1;
# }
# #T_2063c_row2_col3 {
#   background-color: #909090;
#   color: #f1f1f1;
# }
# #T_2063c_row2_col5 {
#   background-color: #b7b7b7;
#   color: #000000;
# }
# #T_2063c_row3_col0 {
#   background-color: #4a4a4a;
#   color: #f1f1f1;
# }
# #T_2063c_row3_col1 {
#   background-color: #464646;
#   color: #f1f1f1;
# }
# #T_2063c_row3_col5 {
#   background-color: #767676;
#   color: #f1f1f1;
# }
# #T_2063c_row4_col0 {
#   background-color: #090909;
#   color: #f1f1f1;
# }
# #T_2063c_row4_col2 {
#   background-color: #363636;
#   color: #f1f1f1;
# }
# #T_2063c_row4_col5 {
#   background-color: #131313;
#   color: #f1f1f1;
# }
# #T_2063c_row5_col0 {
#   background-color: #404040;
#   color: #f1f1f1;
# }
# #T_2063c_row5_col1 {
#   background-color: #848484;
#   color: #f1f1f1;
# }
# #T_2063c_row5_col2 {
#   background-color: #c4c4c4;
#   color: #000000;
# }
# #T_2063c_row5_col3 {
#   background-color: #acacac;
#   color: #000000;
# }
# #T_2063c_row5_col4 {
#   background-color: #6f6f6f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2063c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >LotArea</th>
#       <th class="col_heading level0 col1" >YearBuilt</th>
#       <th class="col_heading level0 col2" >OverallQual</th>
#       <th class="col_heading level0 col3" >1stFlrSF</th>
#       <th class="col_heading level0 col4" >2ndFlrSF</th>
#       <th class="col_heading level0 col5" >SalePrice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2063c_level0_row0" class="row_heading level0 row0" >LotArea</th>
#       <td id="T_2063c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_2063c_row0_col1" class="data row0 col1" >0.014228</td>
#       <td id="T_2063c_row0_col2" class="data row0 col2" >0.105806</td>
#       <td id="T_2063c_row0_col3" class="data row0 col3" >0.299475</td>
#       <td id="T_2063c_row0_col4" class="data row0 col4" >0.050986</td>
#       <td id="T_2063c_row0_col5" class="data row0 col5" >0.263843</td>
#     </tr>
#     <tr>
#       <th id="T_2063c_level0_row1" class="row_heading level0 row1" >YearBuilt</th>
#       <td id="T_2063c_row1_col0" class="data row1 col0" >0.014228</td>
#       <td id="T_2063c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_2063c_row1_col2" class="data row1 col2" >0.572323</td>
#       <td id="T_2063c_row1_col3" class="data row1 col3" >0.281986</td>
#       <td id="T_2063c_row1_col4" class="data row1 col4" >0.010308</td>
#       <td id="T_2063c_row1_col5" class="data row1 col5" >0.522897</td>
#     </tr>
#     <tr>
#       <th id="T_2063c_level0_row2" class="row_heading level0 row2" >OverallQual</th>
#       <td id="T_2063c_row2_col0" class="data row2 col0" >0.105806</td>
#       <td id="T_2063c_row2_col1" class="data row2 col1" >0.572323</td>
#       <td id="T_2063c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_2063c_row2_col3" class="data row2 col3" >0.476224</td>
#       <td id="T_2063c_row2_col4" class="data row2 col4" >0.295493</td>
#       <td id="T_2063c_row2_col5" class="data row2 col5" >0.790982</td>
#     </tr>
#     <tr>
#       <th id="T_2063c_level0_row3" class="row_heading level0 row3" >1stFlrSF</th>
#       <td id="T_2063c_row3_col0" class="data row3 col0" >0.299475</td>
#       <td id="T_2063c_row3_col1" class="data row3 col1" >0.281986</td>
#       <td id="T_2063c_row3_col2" class="data row3 col2" >0.476224</td>
#       <td id="T_2063c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_2063c_row3_col4" class="data row3 col4" >-0.202646</td>
#       <td id="T_2063c_row3_col5" class="data row3 col5" >0.605852</td>
#     </tr>
#     <tr>
#       <th id="T_2063c_level0_row4" class="row_heading level0 row4" >2ndFlrSF</th>
#       <td id="T_2063c_row4_col0" class="data row4 col0" >0.050986</td>
#       <td id="T_2063c_row4_col1" class="data row4 col1" >0.010308</td>
#       <td id="T_2063c_row4_col2" class="data row4 col2" >0.295493</td>
#       <td id="T_2063c_row4_col3" class="data row4 col3" >-0.202646</td>
#       <td id="T_2063c_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_2063c_row4_col5" class="data row4 col5" >0.319334</td>
#     </tr>
#     <tr>
#       <th id="T_2063c_level0_row5" class="row_heading level0 row5" >SalePrice</th>
#       <td id="T_2063c_row5_col0" class="data row5 col0" >0.263843</td>
#       <td id="T_2063c_row5_col1" class="data row5 col1" >0.522897</td>
#       <td id="T_2063c_row5_col2" class="data row5 col2" >0.790982</td>
#       <td id="T_2063c_row5_col3" class="data row5 col3" >0.605852</td>
#       <td id="T_2063c_row5_col4" class="data row5 col4" >0.319334</td>
#       <td id="T_2063c_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Select the independent variables from the new dataframe
X_columns = ["LotArea", "YearBuilt", "OverallQual", "1stFlrSF", "2ndFlrSF"]
X = new_df[X_columns]

# %%
#Select the target variable from the new dataframe
y_columns = ["SalePrice"]
y = new_df[y_columns]

# %%
#Instantiate the Linear regression model
model = LinearRegression()

# %%
#Fit the linear regression on the new regression model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#Get the coeffecient tha create the regression equation
coeffecient: list = model.coef_
coeffecient
# Out:
# array([[7.00857101e-01, 4.41315170e+02, 2.43769434e+04, 7.88854424e+01,
#         4.83187879e+01]])

# %%
#Check the cost function on the trained model
score: float = model.score(X, y)
score
# Out:
# 0.7639947415631084
